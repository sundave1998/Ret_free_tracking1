# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
retraction_free_time = []

retraction_time = []
retraction_time_retraction = []
# changing dimension
dimension = []

# dimension.append(1000)
# retraction_free_time.append(123.27846169471741)
# retraction_time.append(211.65206575393677)

# dimension.append(1000) # r=d/100
# retraction_free_time.append(638.7663009166718)
# retraction_time.append(1085.7651417255402)

# dimension.append(500)
# retraction_free_time.append(34.137083768844604)
# retraction_time.append(53.4998300075531)
# # 29.399209022521973
# # 45.57715320587158


# dimension.append(300)
# retraction_free_time.append(7.90181827545166)
# retraction_time.append(12.799596548080444)


# dimension.append(100)
# retraction_free_time.append(3.2091784477233887)
# retraction_time.append(3.590099811553955)


# dimension.append(50)
# retraction_free_time.append(1.5651731491088867)
# retraction_time.append(1.5984487533569336)

# dimension.append(1000) # r=d/100
# retraction_free_time.append(638.7663009166718)
# retraction_time.append(1085.7651417255402)
# print(1085.76514/638.766300)

# dimension.append(700)
# time1 = 66.04319834709167
# time2 =  156.57880806922913
# retraction_free_time.append(time1)
# retraction_time.append(time2)
# print(time2/time1)

dimension.append(1000)
time1 = 42.9548826
time2 = 95.04421
time3 = 53.0346391
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(500)
time1 = 11.05429
time2 = 42.14180493354
time3 = 24.890235900
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(200)
time1 = 11.51496
time2 = 28.729163
time3 = 17.2528898
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(100)
time1 = 4.72396
time2 = 21.4732
time3 = 16.794278
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

label1 = "DRFGT (This paper)"
label2 = "DRGTA (Chen et al. 2021a)"
label3 = "Retraction Time for DRGTA"

plt.rcParams["figure.figsize"] = (6,4)

# figure(figsize=(4,3))
x = np.arange(len(dimension))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

# for i in range(len(dimension)):
offset = width * multiplier
rects = ax.bar(x + offset, retraction_free_time, width, label=label1)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.2f')

multiplier += 1

offset = width * multiplier

rects = ax.bar(x + offset, retraction_time, width, label=label2)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.2f')
multiplier += 1

offset = width * multiplier

rects = ax.bar(x + offset, retraction_time_retraction, width, label=label3)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.2f')
multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('CPU time (s)')
ax.set_xlabel('Problem Dimension(d)')
ax.set_title('Elapsed Time for Convergence')
ax.set_xticks(x + width*(0.5+0.5), dimension)
ax.legend(loc='upper right')
ax.set_ylim(0, 120)

# plt.show()
# plt.savefig("time_comp_r5.pdf")
# Out:
# 2.2126520722931744
# 3.8122579499488434
# 2.4949424922014494
# 4.545593104090636

# %%
retraction_free_time = []

retraction_time = []
retraction_time_retraction = []
# changing dimension
dimension = []


dimension.append(1000)
time1 = 105.35591
time2 = 239.084108
time3 = 133.460422015
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(500)
time1 = 23.499834
time2 = 78.1612956
time3 = 43.03638696
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(200)
time1 = 18.16624808
time2 = 43.3374300
time3 = 25.464455
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(100)
# dimension.append(5)
time1 = 9.236289
time2 = 29.9378614
time3 = 17.655983
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)


dimension.append(50)
# dimension.append(5)
time1 = 4.2962605
time2 = 4.6245357
time3 = 0.7052443
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

label1 = "DRFGT (This paper)"
label2 = "DRGTA (Chen et al. 2021a)"
label3 = "Retraction Time for DRGTA"

plt.rcParams["figure.figsize"] = (5,3)

# figure(figsize=(4,3))
x = np.arange(len(dimension))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

# for i in range(len(dimension)):
offset = width * multiplier
rects = ax.barh(x + offset, retraction_free_time, width, label=label1)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')

multiplier += 1

offset = width * multiplier

rects = ax.barh(x + offset, retraction_time, width, label=label2)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')
multiplier += 1

offset = width * multiplier

rects = ax.barh(x + offset, retraction_time_retraction, width, label=label3)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')
multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('CPU time (s)')
ax.set_ylabel('Problem Dimension(d)')
ax.set_title('Elapsed Time for Convergence')
ax.set_yticks(x + width*(0.5+0.5), dimension)
ax.set_xlim(0, 270)
plt.gca().invert_yaxis()
ax.legend(loc='lower right')

# plt.show()
# plt.savefig("time_comp_r5N10_small.pdf")
# plt.savefig("time_comp_r5N10_horizontal.pdf")
# Out:
# 2.269299444141292
# 3.326036073276092
# 2.385601573266636
# 3.2413300839763677
# 1.076409519394832

# %%
retraction_free_time = []

retraction_time = []
retraction_time_retraction = []
# changing rank
dimension = []


dimension.append(20)
time1 = 200.3112
time2 = 1168.1424674
time3 = 913.2595
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(15)
time1 = 71.0022
time2 = 330.584790
time3 = 244.1243689
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(10)
time1 = 27.267059
time2 = 112.418164
time3 = 76.622007
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(5)
time1 = 9.236289
time2 = 29.9378614
time3 = 17.655983
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(2)
time1 = 5.2365
time2 = 14.379583
time3 = 7.4130342
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

# species = ("Adelie", "Chinstrap", "Gentoo")
label1 = "DRFGT (This paper)"
label2 = "DRGTA (Chen et al. 2021a)"
label3 = "Retraction Time for DRGTA"

plt.rcParams["figure.figsize"] = (6,4)

# figure(figsize=(4,3))
x = np.arange(len(dimension))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

# for i in range(len(dimension)):
offset = width * multiplier
rects = ax.bar(x + offset, retraction_free_time, width, label=label1)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')

multiplier += 1

offset = width * multiplier

rects = ax.bar(x + offset, retraction_time, width, label=label2)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')
multiplier += 1

offset = width * multiplier

rects = ax.bar(x + offset, retraction_time_retraction, width, label=label3)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')
multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('CPU time (s)')
ax.set_xlabel('Problem Dimension (r)')
ax.set_title('Elapsed Time for Convergence')
ax.set_xticks(x + width*(0.5+0.5), dimension)
ax.legend(loc='upper right')
ax.set_ylim(0, 1260)

# plt.savefig("time_comp_d500.pdf")
# Out:
# 5.831638307793074
# 4.655979533028554
# 4.122856227362107
# 3.2413300839763677
# 2.746029408956364
# (0.0, 1260.0)

# %%
# for 10 anent, d=100
retraction_free_time = []

retraction_time = []
retraction_time_retraction = []
# changing rank
dimension = []


dimension.append(20)
time1 = 158.22689
time2 = 939.2205
time3 = 762.97672
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(15)
time1 = 60.47169137
time2 = 309.663969
time3 = 252.3781
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(10)
time1 = 23.263743
time2 = 128.452811
time3 = 105.06206
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(5)
time1 = 8.72421312
time2 = 34.264496
time3 = 26.35380339
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

dimension.append(2)
time1 = 6.1051795
time2 = 12.9009757
time3 = 7.98298
retraction_free_time.append(time1)
retraction_time.append(time2)
retraction_time_retraction.append(time3)
print(time2/time1)

# species = ("Adelie", "Chinstrap", "Gentoo")
label1 = "DRFGT (This paper)"
label2 = "DRGTA (Chen et al. 2021a)"
label3 = "Retraction Time for DRGTA"

plt.rcParams["figure.figsize"] = (5,3)

# figure(figsize=(4,3))
x = np.arange(len(dimension))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

# for i in range(len(dimension)):
offset = width * multiplier
rects = ax.barh(x + offset, retraction_free_time, width, label=label1)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')

multiplier += 1

offset = width * multiplier

rects = ax.barh(x + offset, retraction_time, width, label=label2)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')
multiplier += 1

offset = width * multiplier

rects = ax.barh(x + offset, retraction_time_retraction, width, label=label3)
rects.datavalues = np.around(rects.datavalues,2)
ax.bar_label(rects, padding=3, fmt='%.1f')
multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('CPU time (s)')
ax.set_ylabel('Problem Dimension (r)')
ax.set_title('Elapsed Time for Convergence')
ax.set_yticks(x + width*(0.5+0.5), dimension)
ax.legend(loc='lower right')
ax.set_xlim(0, 1100)
plt.gca().invert_yaxis()

plt.savefig("time_comp_d100N10_horizontal.pdf")
# Out:
# 5.935909503119223
# 5.120808794735056
# 5.5215882929930915
# 3.9275170756030318
# 2.1131198026200537
